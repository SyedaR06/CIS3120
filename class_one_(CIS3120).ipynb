# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedaR06/CIS3120/blob/main/class_one_(CIS3120).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
start="hello world"

# %%
print(start)
# Out:
# None

# %% [markdown]
# # HELLO WORLD PROGRAM
